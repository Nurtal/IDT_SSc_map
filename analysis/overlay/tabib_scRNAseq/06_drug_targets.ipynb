# %% [markdown]
# # 06 — Druggable hub prioritisation
#
# **Inputs.**
# - `analysis/network/centrality.tsv` (top-20 hubs by intersection of degree + betweenness) from Phase 3 / week 14.
# - DGIdb (`https://dgidb.org/`) and Open Targets (`https://platform.opentargets.org/`) APIs.
#
# **Outputs.** `analysis/overlay/druggable_hubs.tsv` — rows = hub gene, columns = `hgnc_symbol, module, hub_score, drug, max_phase, mechanism, source, source_id, notes`.
#
# **Steps.**
# 1. Load top-20 hubs.
# 2. Query DGIdb for drug-gene interactions per hub.
# 3. Query Open Targets for tractability and SSc disease association evidence.
# 4. Annotate `max_phase` from ChEMBL.
# 5. Sort by combined score (hub_score × max_phase × SSc association).
# 6. Write the table; carry top entries to figure F3.

# %%
import pandas as pd

# TODO: implement during Phase 4 (week 16).
