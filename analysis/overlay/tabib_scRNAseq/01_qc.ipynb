# %% [markdown]
# # 01 — QC of Tabib et al. 2021 SSc skin scRNAseq
#
# **Inputs.** Raw or pre-quantified counts for the dataset associated with Tabib *Nat Commun* 2021 (GEO: GSE138669 or equivalent re-analysis). Place the raw or `.h5ad` file under `data/raw/tabib2021/` (gitignored).
#
# **Outputs.** `data/processed/tabib2021/qc.h5ad` with QC metrics computed.
#
# **Steps.**
# 1. Load counts → AnnData.
# 2. Per-cell metrics: n_genes, total_counts, pct_counts_mt, pct_counts_ribo.
# 3. Filter: cells with `n_genes >= 200` and `pct_counts_mt <= 20`; genes detected in `>= 3` cells.
# 4. Diagnostic plots: violin + scatter (`n_genes` × `pct_counts_mt`).
# 5. Save filtered AnnData.

# %%
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 1
sc.settings.set_figure_params(dpi=100)

# TODO: implement during Phase 4 (week 15).
