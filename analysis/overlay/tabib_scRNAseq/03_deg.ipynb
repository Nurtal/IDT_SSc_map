# %% [markdown]
# # 03 — Differential expression per cell type (SSc vs HC)
#
# **Inputs.** `data/processed/tabib2021/clustered.h5ad` from `02_clustering.ipynb`.
#
# **Outputs.** `data/processed/tabib2021/deg/<cluster>.tsv` per annotated cluster.
#
# **Steps.**
# 1. For each annotated cell type, subset cells of that type.
# 2. Wilcoxon rank-sum test SSc vs healthy control on log-normalised counts.
# 3. FDR (Benjamini-Hochberg). Report effect size as log2 fold-change of means.
# 4. Filter to `padj < 0.05` and `|log2FC| >= 0.5`.
# 5. Save per-cluster DEG tables.
#
# These DEG tables feed the MIM projection in `04_projection.ipynb`.

# %%
import scanpy as sc

# TODO: implement during Phase 4 (week 15).
