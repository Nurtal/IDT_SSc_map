# %% [markdown]
# # 04 — Project per-cluster DEGs onto the MIM
#
# **Inputs.**
# - `data/processed/tabib2021/deg/<cluster>.tsv` per cluster.
# - `curation/annotations/species_annotations.tsv` for the HGNC → species_id map.
#
# **Outputs.** `minerva/overlays/tabib_<cluster>.tsv` — one MINERVA-compatible overlay per cluster, columns `species_id`, `value` (log2FC, sign-encoded), `color`.
#
# **Steps.**
# 1. Load `species_annotations.tsv`; build `hgnc_symbol -> species_id` lookup.
# 2. For each cluster DEG table, join on HGNC symbol; drop unmatched.
# 3. Encode value = clipped log2FC (range [-3, 3]); colour = diverging palette.
# 4. Save MINERVA overlay TSVs ready for upload.

# %%
import pandas as pd

# TODO: implement during Phase 4 (week 16).
