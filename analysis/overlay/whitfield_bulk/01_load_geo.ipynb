# %% [markdown]
# # 01 — Load Whitfield / GENISOS / PRESS bulk SSc skin
#
# **Inputs.**
# - GSE58095 (Hinchcliff / Whitfield) — 61 SSc + 36 HC dcSSc skin, Agilent.
# - GSE45485 (Pendergrass / Whitfield) — longitudinal SSc skin cohort.
# - Both retrieved via `GEOquery` (R) or `GEOparse` (Python).
#
# **Outputs.** `data/processed/whitfield/expression_matrix.tsv` — gene × sample log-counts; `sample_metadata.tsv` — cohort, autoAb, mRSS, intrinsic subset if previously annotated.
#
# **Steps.**
# 1. Download SOFT files from GEO. Mirror locally under `data/raw/whitfield/` (gitignored).
# 2. Normalise (quantile / RMA depending on platform).
# 3. Collapse multi-probe genes by `max(median expression)`.
# 4. Harmonise cohort labels (cohort, treatment, mRSS, autoAb, disease duration).
# 5. Write the merged matrix + metadata.
#
# This is the **reserve** path per `docs/omics_decision.md`; on the primary path (Tabib scRNAseq) the Whitfield projection still ships as a 1-day complementary panel in week 16.

# %%
import pandas as pd

# TODO: implement during Phase 4 / week 16.
