# %% [markdown]
# # 02 — Assign intrinsic subsets (Milano / Pendergrass / Mahoney)
#
# **Inputs.** `data/processed/whitfield/expression_matrix.tsv` + `sample_metadata.tsv` from `01_load_geo.ipynb`.
#
# **Outputs.** `data/processed/whitfield/intrinsic_subsets.tsv` — donor × subset assignment + confidence.
#
# **Steps.**
# 1. Project each sample onto Milano 2008 / Pendergrass 2012 intrinsic-subset signatures (inflammatory, fibroproliferative, limited, normal-like). Use ssGSEA or weighted z-score.
# 2. Hard-assign each donor to its top subset; flag ambiguous donors (delta-score < threshold).
# 3. Optionally cluster on the SSc-MIM module-gene subset (subset × four MIM modules); compare to the published intrinsic subsets — this is the sanity check that the MIM recovers known structure.
# 4. Save the subset table for the projection step.

# %%
import pandas as pd
import numpy as np

# TODO: implement during Phase 4 / week 16.
