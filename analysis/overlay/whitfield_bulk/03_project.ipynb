# %% [markdown]
# # 03 — Project intrinsic subsets onto the SSc-MIM
#
# **Inputs.**
# - `data/processed/whitfield/expression_matrix.tsv`
# - `data/processed/whitfield/intrinsic_subsets.tsv`
# - `curation/annotations/species_annotations.tsv` (HGNC → MIM species id)
#
# **Outputs.**
# - `analysis/overlay/whitfield_bulk/subset_module_scores.tsv` — subset × MIM module activation score.
# - `minerva/overlays/whitfield_<subset>.tsv` — per-subset overlay (mean log2FC per MIM species, MINERVA-formatted).
# - A heatmap (3 subsets × 4 modules) for the composite F2 panel.
#
# **Steps.**
# 1. Compute mean SSc-vs-HC log-fold-change per intrinsic subset, per HGNC gene.
# 2. Join on `species_annotations.tsv:hgnc_symbol` to map to MIM species ids.
# 3. For each (subset, module), score = mean z-scored expression of module's species. Bootstrap CI optional.
# 4. Output the MINERVA overlay TSV per subset.
# 5. Sanity check: subsets cluster on M1 (inflammatory ↑) and M2 (fibroproliferative ↑) as expected.
#
# Companion panel to the Tabib scRNAseq overlay; shipped as a small inset in figure F2.

# %%
import pandas as pd

# TODO: implement during Phase 4 / week 16.
